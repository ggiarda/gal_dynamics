# %% [markdown]
# # Truncated sphere simulation results:
#
# We decided to run the simulation we set up from the "$\texttt{_ SETTINGS}$" notebook for $3 \cdot T_{coll} \sim 3. 33$.
#
# As for the previous $\textit{hands-on}$ session, we produced some plots and animations to better understand the result.
#
#
#
# ![](N_100.gif)

# %% [markdown]
# Here there are just some code pieces to get the data from the output files.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

fname = 'output.txt'

N = 1000

# %%
data = pd.read_csv(fname, header=None).to_numpy()

# %%
N = 1000

# take only the paired components every 3N+3 rows
# index 1: times
#index i: masses
# index i + N : positions
#index i + 2N : velocities

times = data[2::(3 * N + 3)].astype(float)

m = {}

for i in range(3, N + 3): # start from index==2 because we care about m_s, x_s and v_s 
    
    m[f"{i}_ms"]= data[i::(3 * N + 3)]
    m[f"{i}_xs"]= data[(i + N)::(3 * N + 3)]
    m[f"{i}_vs"]= data[(i + 2 * N)::(3 * N + 3)]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 9
#       1 N = 1000
#       3 # take only the paired components every 3N+3 rows
#       4 # index 1: times
#       5 #index i: masses
#       6 # index i + N : positions
#       7 #index i + 2N : velocities
# ----> 9 times = data[2::(3 * N + 3)].astype(float)
#      11 m = {}
#      13 for i in range(3, N + 3): # start from index==2 because we care about m_s, x_s and v_s
#
# ValueError: could not convert string to float: ' -1.1729082E-01 -2.2962344E-01  2.3070799E-01'

# %%
len(m)
# Out:
# 3000

# %%
m_data = {} # define a dictionary to order variables

for j in range(3, N + 3):

    m_data[f"{j - 3}_ms"] = np.array([m[f"{j}_ms"][i][0].split() for i in range(0, len(m[f"{j}_ms"]))]).astype(float)
    m_data[f"{j - 3}_xs"] = np.array([m[f"{j}_xs"][i][0].split() for i in range(0, len(m[f"{j}_xs"]))]).astype(float)
    m_data[f"{j - 3}_vs"] = np.array([m[f"{j}_xs"][i][0].split() for i in range(0, len(m[f"{j}_vs"]))]).astype(float)

# %%
times_plot = np.hstack(times) # create array from the previous times

# %% [markdown]
# Finally getting to the actual 3D plot:

# %%
fig, ax = plt.subplots(subplot_kw=dict(projection='3d'), figsize=(8,8))

for i in range(0, N):

    ax.plot(m_data[f"{i}_xs"][:, 0], m_data[f"{i}_xs"][:, 1], m_data[f"{i}_xs"][:, 2], label=f"{i}th particle", linestyle='-')

    
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("z")

ax.set_xlim(-1, 1)
ax.set_ylim(-1, 1)
ax.set_zlim(-1, 1)

plt.show()

#plt.legend()

# %% [markdown]
# Let's see some animation.

# %%
import matplotlib.animation as animation

def update(num):
    
    ax.clear() 
    
    for i in range(0, N): 
    
        ax.scatter(m_data[f"{i}_xs"][num, 0], m_data[f"{i}_xs"][num, 1], m_data[f"{i}_xs"][num, 2], s=2.5)             
        
    
        ax.set_xlabel(r'$x$')
        ax.set_ylabel(r'$y$')
        ax.set_zlabel(r'$z$')
        
        ax.set_xlim(-0.5, 0.5)
        ax.set_ylim(-0.5, 0.5)
        ax.set_zlim(-0.5, 0.5)

# %%
## Plotting the Animation

# %matplotlib notebook

fig = plt.figure()
ax = plt.axes(projection='3d')
numDataPoints = int(len(m_data["100_xs"][:, 2]) / 3)
line_ani = animation.FuncAnimation(fig, update, interval=15, frames=numDataPoints)

# Saving the Animation
f = r"N_100.gif"
writergif = animation.PillowWriter(fps=10)
line_ani.save(f, writer=writergif);


plt.close()
# Out:
# <div id='380363c8-e603-4ece-be65-1bdabff2aa6f'></div>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 13
#      11 f = r"N_100.gif"
#      12 writergif = animation.PillowWriter(fps=10)
# ---> 13 line_ani.save(f, writer=writergif);
#      16 plt.close()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/animation.py:1095, in Animation.save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1092 for data in zip(*[a.new_saved_frame_seq() for a in all_anim]):
#    1093     for anim, d in zip(all_anim, data):
#    1094         # TODO: See if turning off blit is really necessary
# -> 1095         anim._draw_next_frame(d, blit=False)
#    1096         if progress_callback is not None:
#    1097             progress_callback(frame_number, total_frames)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/animation.py:1130, in Animation._draw_next_frame(self, framedata, blit)
#    1126 def _draw_next_frame(self, framedata, blit):
#    1127     # Breaks down the drawing of the next frame into steps of pre- and
#    1128     # post- draw, as well as the drawing of the frame itself.
#    1129     self._pre_draw(framedata, blit)
# -> 1130     self._draw_frame(framedata)
#    1131     self._post_draw(framedata, blit)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/animation.py:1759, in FuncAnimation._draw_frame(self, framedata)
#    1755     self._save_seq = self._save_seq[-self._save_count:]
#    1757 # Call the func with framedata and args. If blitting is desired,
#    1758 # func needs to return a sequence of any artists that were modified.
# -> 1759 self._drawn_artists = self._func(framedata, *self._args)
#    1761 if self._blit:
#    1763     err = RuntimeError('The animation function must return a sequence '
#    1764                        'of Artist objects.')
#
# Cell In[12], line 18, in update(num)
#      16 ax.set_xlim(-0.5, 0.5)
#      17 ax.set_ylim(-0.5, 0.5)
# ---> 18 ax.set_zlim(-0.5, 0.5)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/_api/deprecation.py:454, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     448 if len(args) > name_idx:
#     449     warn_deprecated(
#     450         since, message="Passing the %(name)s %(obj_type)s "
#     451         "positionally is deprecated since Matplotlib %(since)s; the "
#     452         "parameter will become keyword-only %(removal)s.",
#     453         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 454 return func(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/mpl_toolkits/mplot3d/axes3d.py:707, in Axes3D.set_zlim(self, bottom, top, emit, auto, zmin, zmax)
#     705         raise TypeError("Cannot pass both 'top' and 'zmax'")
#     706     top = zmax
# --> 707 return self.zaxis._set_lim(bottom, top, emit=emit, auto=auto)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/axis.py:1178, in Axis._set_lim(self, v0, v1, emit, auto)
#    1158 """
#    1159 Set view limits.
#    1160
#    (...)
#    1173     turns off, None leaves unchanged.
#    1174 """
#    1175 name, = [name for name, axis in self.axes._axis_map.items()
#    1176          if axis is self]  # The axis name.
# -> 1178 self.axes._process_unit_info([(name, (v0, v1))], convert=False)
#    1179 v0 = self.axes._validate_converted_limits(v0, self.convert_units)
#    1180 v1 = self.axes._validate_converted_limits(v1, self.convert_units)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/axes/_base.py:2550, in _AxesBase._process_unit_info(self, datasets, kwargs, convert)
#    2546         raise ValueError(f"Invalid axis name: {axis_name!r}") from None
#    2547     # Update from data if axis is already set but no unit is set yet.
#    2548     if (axis is not None and
#    2549             data is not None and
# -> 2550             not axis._have_units_and_converter()):
#    2551         axis.update_units(data)
#    2552 for axis_name, axis in axis_map.items():
#    2553     # Return if no axis is set.
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/axis.py:1719, in Axis._have_units_and_converter(self)
#    1714     """
#    1715     Return `True` if units or a converter have been set.
#    1716     """
#    1717     return self.converter is not None or self.units is not None
# -> 1719 def _have_units_and_converter(self):
#    1720     """
#    1721     Return `True` if units and a converter have been set.
#    1722     """
#    1723     return self.converter is not None and self.units is not None
#
# KeyboardInterrupt:

# %% [markdown]
# ## Comments and observations

# %% [markdown]
# The simulation result provides a deep insight on the theory we explained at the beginning. We see that as times passes come of the masses are scattered around and others remain bound. This behaviour was expected because of the random generated points that were not placed at the exact opposites of the sphere, making it difficult to obtain a collapse in the same $R=0$ point. We can eventually check whether it is correct that the trajectories vary the way we see in the 3D plot.

# %% [markdown]
# ## $R$ analysis

# %% [markdown]
# Goal: see how the distances oh the masses change over time. Check with the results of the dynamical and free-fall time.

# %%
r_t = {}  # set an array where to store rays at different ts

for i in range(0, N):  
    
    r_t[f"{i}"] = np.sqrt(m_data[f"{i}_xs"][:, 0]**2 + m_data[f"{i}_xs"][:, 1]**2 + m_data[f"{i}_xs"][:, 2]**2)

# %% [markdown]
# Let's see how different masses behave depending on their initial $\textit{relative}$ position:

# %%
plt.figure(figsize = (8,8))

for i in range(0, N):

    plt.plot(times_plot, r_t[f"{i}"][:], label = f"{i} mass")

plt.xlabel("$t$ [IU]")
plt.ylabel("$\mathrm{R}(t)$ [IU]")
plt.title("Radii from (0,0,0) over time")
plt.ylim(0, 1.5)
plt.show()

# %% [markdown]
# Observation: we noticed that changing the $\epsilon$ value changes the outcome drastically. Indeed, if $\epsilon > 0.5$ we obtain a periodic system, where most of the particles do not scatter outside the bulk (if not all of them).

# %% [markdown]
# ## $R_{min}$ analysis
#
# We want to see if the $T_{coll}$ we indicated in the previous notebook is relatable to what we observe in the simulation or not. To do so we first take the sum of the $r$ values, and then we evaluate its minimum. The time $t_{min}$ will be out estimation of the "$\textit{average}$" collapse time found for the masses (e.g. when the majority of masses reaches $R \sim 0$.

# %%
def GetSumRs(): 
    
    for i in range(0, len(times_plot)): 
    
        summation = 0
    
        for j in range(0, N):
        
            summation += r_t[f"{j}"][i]
    
        sum_Rs.append(summation)
        
    return np.array(sum_Rs)

# %%
sum_Rs = []
sum_Rs = GetSumRs()

# %%
plt.figure(figsize = (8,8))

plt.plot(times_plot, sum_Rs, label = "$\sum R$")

plt.xlabel("$t$ [IU]")
plt.ylabel("$\mathrm{R}(t)$ [IU]")
plt.legend()
plt.show()

# %% [markdown]
# Now let's check the minimum:

# %%
print("sum_R_min: ", sum_Rs.min())
print("t_min: ", times_plot[sum_Rs.argmin()])

# %% [markdown]
# For the sake of completeness I here report the value of the $T_{coll}$ we analitically estimated n the other notebook:

# %%
T_coll = 1.1107207345395915
print("T_coll: ", T_coll)

# %% [markdown]
# The $\textbf{relative}$ error is roughly estimated as:

# %%
err = np.abs(times_plot[sum_Rs.argmin()] - T_coll) / T_coll
print("rel_err: ", err)

# %% [markdown]
# # Analytical solution check:

# %% [markdown]
# From this integral:
#
# $$\frac{dr}{dt} = - \sqrt{2GM_{0}(\frac{1}{r} - \frac{1}{r_{0}})}$$
#
# We can extract the value of $t$ as a function of $r$:
#
# $$t = -\sqrt{\frac{3}{{8G\pi\rho_0}}} (\arcsin{\sqrt{\frac{r}{r_0}}} - \sqrt{\frac{r}{r_0}}\sqrt{1 - \frac{r}{r_0}} - \frac{\pi}{2})$$

# %%
def T_r(r0, rs, rho0): 
    
    return 3**0.5 / -(8 * np.pi * rho0)**(0.5) * (np.arcsin((rs / r0)**(0.5)) - (rs/r0)**(0.5) * (1 - rs/r0)**(0.5) - np.pi/2)

# %%
def r0(m_data): 
    
    return np.sqrt(m_data[0, 0]**2 + m_data[0, 1]**2 + m_data[0, 2]**2)

# %% [markdown]
# Here we load the initial data that is needed to evaluate $r_0$:

# %%
fname_init = 'homogeneous_sphere_initial.txt'

# %%
data_init = pd.read_csv(fname_init, header=None).to_numpy()

# %%
# params:

N = 1000
M = 1 
a = 1
V_sphere = 4/3 * np.pi * a**3
rho0 = M / V_sphere

# take only the paired components every 3N+3 rows
# index 2: times
#index i: masses
# index i + N : positions
#index i + 2N : velocities


m_init = {}

for i in range(3, N + 3): # start from index==2 because we care about m_s, x_s and v_s 
    
    m_init[f"{i}_ms"]= data_init[i::(3 * N + 3)]
    m_init[f"{i}_xs"]= data_init[(i + N)::(3 * N + 3)]
    m_init[f"{i}_vs"]= data_init[(i + 2 * N)::(3 * N + 3)]

# %%
m_data_init = {} # define a dictionary to order variables

for j in range(3, N + 3):

    m_data_init[f"{j - 3}_ms"] = np.array([m_init[f"{j}_ms"][i][0].split() for i in range(0, len(m_init[f"{j}_ms"]))]).astype(float)
    m_data_init[f"{j - 3}_xs"] = np.array([m_init[f"{j}_xs"][i][0].split() for i in range(0, len(m_init[f"{j}_xs"]))]).astype(float)
    m_data_init[f"{j - 3}_vs"] = np.array([m_init[f"{j}_xs"][i][0].split() for i in range(0, len(m_init[f"{j}_vs"]))]).astype(float)

# %%
# set values to get analytical solution:

r0_s = [r0(m_data_init[f"{j}_xs"]) for j in range(0, N)]

r_s = [np.linspace(0, r0_s[j]) for j in range(0, len(r0_s))]

# %%
t_s= [] # evaluate t_s as function of r_s and r_0 and then revert axes

for i in range(0, N): 

    t_s.append(T_r(r0_s[i], r_s[i], rho0))

# %%
plt.figure(figsize = (8,8))

for i in range(0, len(t_s)):

    plt.plot(t_s[i], r_s[i]) # revert axes to get r(t)
    
plt.xlabel("time [IU]")
plt.ylabel("rays [IU]")

plt.suptitle("Analytic rays")
    
plt.show();

# %%
plt.figure(figsize = (8,8))

for i in range(0, len(t_s)):

    plt.plot(t_s[i], r_s[i], c='black') # revert axes to get r(t)
    
for i in range(0, N):

    plt.plot(times_plot[:20], r_t[f"{i}"][:20], label = f"{i} mass")
    
plt.xlabel("time [IU]")
plt.ylabel("rays [IU]")

plt.suptitle("Analytic rays vs solutions")
    
plt.show();

# %% [markdown]
# Choose one component and compare it:

# %%
plt.plot(times_plot[:20], r_t[f"34"][:20])
plt.plot(t_s[34], r_s[34])

plt.show()

# %% [markdown]
# Interestingly we have an error on the collapse time. A huge one indeed. Let's double check the error by the use of the $L^{2}$ norm.

# %%
l2_norm_rs = []

for i in range(0, len(r_s)): 
    
    l2_norm_rs.append(np.sqrt(np.sum(r_s[i]**2)/len(r_s[i])))
    
l2_norm_rt = []

for i in range(0, len(r_t)): 
    
    l2_norm_rt.append(np.sqrt(np.sum(r_t[f"{i}"]**2)/len(r_t[f"{i}"])))

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(9, 6))

ax1.plot(range(0, len(l2_norm_rs)), l2_norm_rs, c='royalblue')
ax2.plot(range(0, len(l2_norm_rt)), l2_norm_rt, c='magenta')

ax1.axhline(y=np.mean(l2_norm_rs), color='r', linestyle='-', label=f'{np.mean(l2_norm_rs)}')
ax2.axhline(y=np.mean(l2_norm_rt), color='aquamarine', linestyle='-', label=f'{np.mean(l2_norm_rt)}')
ax1.legend()
ax2.legend()

ax1.set_xlabel("vec component")
ax2.set_xlabel("vec component")

ax1.set_ylabel(r"$L^{2}$ norm [IU]")
ax2.set_ylabel(r"$L^{2}$ norm [IU]");

# %% [markdown]
# Idk what I am doing, we need discussion on this.
