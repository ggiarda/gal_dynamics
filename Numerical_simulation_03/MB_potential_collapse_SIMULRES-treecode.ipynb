# %% [markdown]
# # Truncated sphere simulation results:
#
# We decided to run the simulation we set up from the "$\texttt{_ SETTINGS}$" notebook for $1 \cdot T_{coll} \sim 1.11$.
#
# As for the previous $\textit{hands-on}$ session, we produced some plots and animations to better understand the result.

# %% [markdown]
# Here there are just some code pieces to get the data from the output files.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

fname = 'output.txt'

# %%
data = pd.read_csv(fname).to_numpy()

# %%
N = 1000
times = data[1::(3 * N + 3)].astype(float)

m = {}

for i in range(2, N):
    
    m[f"{i}_ms"]= data[i::(3*N+3)]
    m[f"{i}_xs"]= data[(i+N)::(3*N+3)]  # take only the components every 3N+1 rows
    m[f"{i}_vs"]= data[(2 * N+i)::(3*N+3)]

# %%
m_data = {}

for j in range(2, N):

    m_data[f"{j}_ms"] = np.array([m[f"{j}_ms"][i][0].split() for i in range(0, len(m[f"{j}_ms"]))]).astype(float)
    m_data[f"{j}_xs"] = np.array([m[f"{j}_xs"][i][0].split() for i in range(0, len(m[f"{j}_xs"]))]).astype(float)
    m_data[f"{j}_vs"] = np.array([m[f"{j}_xs"][i][0].split() for i in range(0, len(m[f"{j}_vs"]))]).astype(float)

# %%
times_plot = np.hstack(times)

# %% [markdown]
# Finally getting to the actual 3D plot:

# %%
fig, ax = plt.subplots(subplot_kw=dict(projection='3d'), figsize=(8,8))

for i in range(2, N):

    ax.plot(m_data[f"{i}_xs"][:, 0], m_data[f"{i}_xs"][:, 1], m_data[f"{i}_xs"][:, 2], label=f"{i}th particle", linestyle='-')

    
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("z")

ax.set_xlim(-1, 1)
ax.set_ylim(-1, 1)
ax.set_zlim(-1, 1)

plt.show()

#plt.legend()

# %% [markdown]
# Let's see some animation.

# %%
import matplotlib.animation as animation

def update(num):
    
    ax.clear() 
    
    for i in range(2, N): 
    
        ax.scatter(m_data[f"{i}_xs"][num, 0], m_data[f"{i}_xs"][num, 1], m_data[f"{i}_xs"][num, 2], s=2.5)             
        
        #ax.scatter(m_data[f"{i}"][num, 1], m_data[f"{i}"][num, 2], m_data[f"{i}"][num, 3], marker='o', size=3.5, c='red')   
    
        ax.set_xlabel(r'$x$')
        ax.set_ylabel(r'$y$')
        ax.set_zlabel(r'$z$')
        
        ax.set_xlim(-0.5, 0.5)
        ax.set_ylim(-0.5, 0.5)
        ax.set_zlim(-0.5, 0.5)

# %%
## Plotting the Animation

# %matplotlib notebook

fig = plt.figure()
ax = plt.axes(projection='3d')
numDataPoints = int(len(m_data["100_xs"][:, 2]) / 3)
line_ani = animation.FuncAnimation(fig, update, interval=15, frames=numDataPoints)

# Saving the Animation
f = r"N_100.gif"
writergif = animation.PillowWriter(fps=40)
line_ani.save(f, writer=writergif);


plt.close()
# Out:
# <img src="data:image/png;base64,..." width="639.6666666666666">
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 13
#      11 f = r"N_100.gif"
#      12 writergif = animation.PillowWriter(fps=40)
# ---> 13 line_ani.save(f, writer=writergif);
#      16 plt.close()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/animation.py:1099, in Animation.save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1097         progress_callback(frame_number, total_frames)
#    1098         frame_number += 1
# -> 1099 writer.grab_frame(**savefig_kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/animation.py:491, in PillowWriter.grab_frame(self, **savefig_kwargs)
#     489 def grab_frame(self, **savefig_kwargs):
#     490     buf = BytesIO()
# --> 491     self.fig.savefig(
#     492         buf, **{**savefig_kwargs, "format": "rgba", "dpi": self.dpi})
#     493     self._frames.append(Image.frombuffer(
#     494         "RGBA", self.frame_size, buf.getbuffer(), "raw", "RGBA", 0, 1))
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/figure.py:3328, in Figure.savefig(self, fname, transparent, **kwargs)
#    3324     for ax in self.axes:
#    3325         stack.enter_context(
#    3326             ax.patch._cm_set(facecolor='none', edgecolor='none'))
# -> 3328 self.canvas.print_figure(fname, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/backend_bases.py:2362, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2358 try:
#    2359     # _get_renderer may change the figure dpi (as vector formats
#    2360     # force the figure dpi to 72), so we need to set it again here.
#    2361     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2362         result = print_method(
#    2363             filename,
#    2364             facecolor=facecolor,
#    2365             edgecolor=edgecolor,
#    2366             orientation=orientation,
#    2367             bbox_inches_restore=_bbox_inches_restore,
#    2368             **kwargs)
#    2369 finally:
#    2370     if bbox_inches and restore_bbox:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/backend_bases.py:2228, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2224     optional_kws = {  # Passed by print_figure for other renderers.
#    2225         "dpi", "facecolor", "edgecolor", "orientation",
#    2226         "bbox_inches_restore"}
#    2227     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2228     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2229         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2230 else:  # Let third-parties do as they see fit.
#    2231     print_method = meth
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/backends/backend_agg.py:445, in FigureCanvasAgg.print_raw(self, filename_or_obj)
#     444 def print_raw(self, filename_or_obj):
# --> 445     FigureCanvasAgg.draw(self)
#     446     renderer = self.get_renderer()
#     447     with cbook.open_file_cm(filename_or_obj, "wb") as fh:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/backends/backend_agg.py:400, in FigureCanvasAgg.draw(self)
#     396 # Acquire a lock on the shared font cache.
#     397 with RendererAgg.lock, \
#     398      (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     399       else nullcontext()):
# --> 400     self.figure.draw(self.renderer)
#     401     # A GUI class may be need to update a window using this draw, so
#     402     # don't forget to call the superclass.
#     403     super().draw()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/figure.py:3125, in Figure.draw(self, renderer)
#    3122         # ValueError can occur when resizing a window.
#    3124 self.patch.draw(renderer)
# -> 3125 mimage._draw_list_compositing_images(
#    3126     renderer, self, artists, self.suppressComposite)
#    3128 for sfig in self.subfigs:
#    3129     sfig.draw(renderer)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129 if not_composite or not has_images:
#     130     for a in artists:
# --> 131         a.draw(renderer)
#     132 else:
#     133     # Composite any adjacent images together
#     134     image_group = []
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/mpl_toolkits/mplot3d/axes3d.py:493, in Axes3D.draw(self, renderer)
#     490         axis.draw(renderer)
#     492 # Then rest
# --> 493 super().draw(renderer)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/axes/_base.py:3066, in _AxesBase.draw(self, renderer)
#    3063 if artists_rasterized:
#    3064     _draw_rasterized(self.figure, artists_rasterized, renderer)
# -> 3066 mimage._draw_list_compositing_images(
#    3067     renderer, self, artists, self.figure.suppressComposite)
#    3069 renderer.close_group('axes')
#    3070 self.stale = False
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129 if not_composite or not has_images:
#     130     for a in artists:
# --> 131         a.draw(renderer)
#     132 else:
#     133     # Composite any adjacent images together
#     134     image_group = []
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/artist.py:39, in _prevent_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      36     renderer.stop_rasterizing()
#      37     renderer._rasterizing = False
# ---> 39 return draw(artist, renderer, *args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/mpl_toolkits/mplot3d/art3d.py:639, in Path3DCollection.draw(self, renderer)
#     637 with self._use_zordered_offset():
#     638     with cbook._setattr_cm(self, _in_draw=True):
# --> 639         super().draw(renderer)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/collections.py:972, in _CollectionWithSizes.draw(self, renderer)
#     969 @artist.allow_rasterization
#     970 def draw(self, renderer):
#     971     self.set_sizes(self._sizes, self.figure.dpi)
# --> 972     super().draw(renderer)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/collections.py:388, in Collection.draw(self, renderer)
#     386 else:
#     387     combined_transform = transform
# --> 388 extents = paths[0].get_extents(combined_transform)
#     389 if (extents.width < self.figure.bbox.width
#     390         and extents.height < self.figure.bbox.height):
#     391     do_single_path_optimization = True
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/path.py:635, in Path.get_extents(self, transform, **kwargs)
#     632 xys = []
#     633 for curve, code in self.iter_bezier(**kwargs):
#     634     # places where the derivative is zero can be extrema
# --> 635     _, dzeros = curve.axis_aligned_extrema()
#     636     # as can the ends of the curve
#     637     xys.append(curve([0, *dzeros, 1]))
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/bezier.py:299, in BezierSegment.axis_aligned_extrema(self)
#     297 roots = []
#     298 for i, pi in enumerate(dCj.T):
# --> 299     r = np.roots(pi[::-1])
#     300     roots.append(r)
#     301     dims.append(np.full_like(r, i))
#
# File <__array_function__ internals>:200, in roots(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/lib/polynomial.py:252, in roots(p)
#     249 N = len(p)
#     250 if N > 1:
#     251     # build companion matrix and find its eigenvalues (the roots)
# --> 252     A = diag(NX.ones((N-2,), p.dtype), -1)
#     253     A[0,:] = -p[1:] / p[0]
#     254     roots = eigvals(A)
#
# File <__array_function__ internals>:200, in diag(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/lib/twodim_base.py:240, in diag(v, k)
#     236 def _diag_dispatcher(v, k=None):
#     237     return (v,)
# --> 240 @array_function_dispatch(_diag_dispatcher)
#     241 def diag(v, k=0):
#     242     """
#     243     Extract a diagonal or construct a diagonal array.
#     244
#    (...)
#     293
#     294     """
#     295     v = asanyarray(v)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Comments and observations

# %% [markdown]
# The simulation result provides a deep insight on the theory we explained at the beginning. We see that as times passes come of the masses are scattered around and others remain bound. This behaviour was expected because of the random generated points that were not placed at the exact opposites of the sphere, making it difficult to obtain a collapse in the same $R=0$ point. We can eventually check whether it is correct that the trajectories vary the way we see in the 3D plot.

# %% [markdown]
# ## $R$ analysis

# %% [markdown]
# Goal: see how the distances oh the masses change over time. Check with the results of the dynamical and free-fall time.

# %%
r_t = {}  # set an array where to store rays at different ts

for i in range(3, N):  
    
    r_t[f"{i}"] = np.sqrt(m_data[f"{i}_xs"][:, 0]**2 + m_data[f"{i}_xs"][:, 1]**2 + m_data[f"{i}_xs"][:, 2]**2)

# %% [markdown]
# Let's see how different masses behave depending on their initial $\textit{relative}$ position:

# %%
plt.figure(figsize = (8,8))

for i in range(3, N):

    plt.plot(times_plot, r_t[f"{i}"][:], label = f"{i} mass")

plt.xlabel("$t$ [IU]")
plt.ylabel("$\mathrm{R}(t)$ [IU]")
plt.title("Radii from (0,0,0) over time")
plt.ylim(0, 1)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="799.9">

# %% [markdown]
# Observation: we noticed that changing the $\epsilon$ value changes the outcome drastically. Indeed, if $\epsilon > 0.5$ we obtain a periodic system, where most of the particles do not scatter outside the bulk (if not all of them).

# %% [markdown]
# ## $R_{min}$ analysis
#
# We want to see if the $T_{coll}$ we indicated in the previous notebook is relatable to what we observe in the simulation or not. To do so we first take the sum of the $r$ values, and then we evaluate its minimum. The time $t_{min}$ will be out estimation of the "$\textit{average}$" collapse time found for the masses (e.g. when the majority of masses reaches $R \sim 0$.

# %%
def GetSumRs(): 
    
    for i in range(0, len(times_plot)): 
    
        summation = 0
    
        for j in range(3, N):
        
            summation += r_t[f"{j}"][i]
    
        sum_Rs.append(summation)
        
    return np.array(sum_Rs)

# %%
sum_Rs = []
sum_Rs = GetSumRs()

# %%
plt.figure(figsize = (8,8))

plt.plot(times_plot, sum_Rs, label = "$\sum R$")

plt.xlabel("$t$ [IU]")
plt.ylabel("$\mathrm{R}(t)$ [IU]")
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="799.9">

# %% [markdown]
# Now let's check the minimum:

# %%
print("sum_R_min: ", sum_Rs.min())
print("t_min: ", times_plot[sum_Rs.argmin()])
# Out:
# sum_R_min:  116.33810797286546
# t_min:  0.69999963

# %% [markdown]
# For the sake of completeness I here report the value of the $T_{coll}$ we analitically estimated n the other notebook:

# %%
T_coll = 1.1107207345395915
print("T_coll: ", T_coll)
# Out:
# T_coll:  1.1107207345395915

# %% [markdown]
# The $\textbf{relative}$ error is roughly estimated as:

# %%
err = np.abs(times_plot[sum_Rs.argmin()] - T_coll) / T_coll
print("rel_err: ", err)

# %% [markdown]
# # Analytical solution check:

# %% [markdown]
# From this integral:
#
# $$\frac{dr}{dt} = - \sqrt{2GM_{0}(\frac{1}{r} - \frac{1}{r_{0}})}$$
#
# We can extract the value of $t$ as a function of $r$:
#
# $$t = \frac{r_0^{3/2}}{-\sqrt{2GM_{0}}} (\arcsin{\sqrt{\frac{r}{r_0}}} - \sqrt{\frac{r}{r_0}}\cos{\arcsin{\sqrt{\frac{r}{r_0}}}} - \frac{\pi}{2})$$

# %%
def Time(r, r0, M0):
    
    return r0**(3/2) / (-np.sqrt(2*M0)) * (np.arcsin(np.sqrt(r/r0)) - np.sqrt(r/r0) * np.cos(np.arcsin(np.sqrt(r/r0))) - np.pi / 2)

# %%
def r0(m_data): 
    
    return np.sqrt(m_data[0, 1]**2 + m_data[0, 2]**2 + m_data[0, 3]**2)

# %%
fname_init = 'homogeneous_sphere_initial.txt'

# %%
data_init = pd.read_csv(fname_init).to_numpy()

# %%
N = 100

m = {}

for i in range(1, N + 1):
    
    m[f"{i}"]= data[i]  # take only the components every N+1 rows

# %%
m_data = {}

for j in range(1, N + 1):

    m_data[f"{j}"] = np.array([m[f"{j}"][i].split() for i in range(0, len(m[f"{j}"]))]).astype(float)
